# %%
import nasdaqdatalink

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# %%
api_key = os.getenv("apikey")

# %%
nasdaqdatalink.ApiConfig.api_key = api_key

# %%
data = nasdaqdatalink.get('NSE/OIL')

# %%
data.head()
# Out:
#               Open    High     Low     Last    Close  Total Trade Quantity  \
# Date
# 2009-09-30  1096.0  1156.7  1090.0  1135.00  1141.20            19748012.0
# 2009-10-01  1102.0  1173.7  1102.0  1167.00  1166.35             3074254.0
# 2009-10-05  1152.0  1165.9  1136.6  1143.00  1140.55              919832.0
# 2009-10-06  1149.8  1157.2  1132.1  1143.30  1144.90              627957.0
# 2009-10-07  1153.8  1160.7  1140.0  1141.45  1141.60              698216.0
#
#             Turnover (Lacs)
# Date
# 2009-09-30        223877.07
# 2009-10-01         35463.78
# 2009-10-05         10581.13
# 2009-10-06          7185.90
# 2009-10-07          8032.98

# %%
import pandas as pd

# %%
hkex_metadata = pd.read_csv("HKEX_metadata.csv")

# %%
hkex_metadata.head()
# Out:
#     code                         name  \
# 0  00000  123 Yuexiu Property (00000)
# 1  00001         Ckh Holdings (00001)
# 2  00002         Clp Holdings (00002)
# 3  00003         Hk China Gas (00003)
# 4  00004       Wharf Holdings (00004)
#
#                                          description         refreshed_at  \
# 0  Stock Prices for 123 Yuexiu Property from the ...  2023-01-16 14:00:38
# 1  Stock Prices for Ckh Holdings from the Hong Ko...  2023-01-16 14:00:38
# 2  Stock Prices for Clp Holdings from the Hong Ko...  2023-01-16 14:00:38
# 3  Stock Prices for Hk China Gas from the Hong Ko...  2023-01-16 14:00:38
# 4  Stock Prices for Wharf Holdings from the Hong ...  2023-01-16 14:00:38
#
#     from_date     to_date
# 0  2017-11-03  2023-01-16
# 1  2014-02-21  2023-01-16
# 2  2014-02-21  2023-01-16
# 3  2014-02-21  2023-01-16
# 4  2014-02-21  2023-01-16

# %%
import requests

# %%
hkex = requests.get("https://data.nasdaq.com/api/v3/datasets/HKEX/00000?api_key=GLNzP3ZArpbbRwX9n3WE")

# %%
hkex.json()
# Out:
# {'dataset': {'id': 40470117,
#   'dataset_code': '00000',
#   'database_code': 'HKEX',
#   'name': '123 Yuexiu Property (00000)',
#   'description': 'Stock Prices for 123 Yuexiu Property from the Hong Kong Stock Exchange. Currency: HKD',
#   'refreshed_at': '2023-01-16T14:00:38.524Z',
#   'newest_available_date': '2023-01-16',
#   'oldest_available_date': '2017-11-03',
#   'column_names': ['Date',
#    'Nominal Price',
#    'Net Change',
#    'Change (%)',
#    'Bid',
#    'Ask',
#    'P/E(x)',
#    'High',
#    'Low',
#    'Previous Close',
#    'Share Volume (000)',
#    'Turnover (000)',
#    'Lot Size'],
#   'frequency': 'daily',
#   'type': 'Time Series',
#   'premium': False,
#   'limit': None,
#   'transform': None,
#   'column_index': None,
#   'start_date': '2017-11-03',
#   'end_date': '2023-01-16',
#   'data': [['2023-01-16',
#     11.08,
#     None,
#     None,
#     11.06,
#     11.08,
#     None,
#     11.16,
#     10.76,
#     10.98,
#     8018.0,
#     88662.0,
# ...

# %%
first_company =  nasdaqdatalink.get('HKEX/00000')
first_company.head()

# %%
zillow = nasdaqdatalink.get_table('ZILLOW/DATA', indicator_id='ZSFH', region_id='99999')
zillow.head()
# Out:
#      indicator_id region_id       date     value
# None
# 0            ZSFH     99999 2022-12-31  551178.0
# 1            ZSFH     99999 2022-11-30  553397.0
# 2            ZSFH     99999 2022-10-31  552233.0
# 3            ZSFH     99999 2022-09-30  569345.0
# 4            ZSFH     99999 2022-08-31  564389.0

# %%
unemploy_rate =  nasdaqdatalink.get('FRED/NROUST')

# %% [markdown]
# unemploy_rate
